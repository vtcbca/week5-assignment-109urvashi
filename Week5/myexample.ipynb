# %%
import csv

# %%
with open('c:\\sqlite3\\CSV\\hello.txt',"r",errors="ignore") as f:
    contents=f.read()
    print(contents)
# Out:
# C:\Users\01>cd C:\sqlite
#
# C:\sqlite>sqlite3 trigger.db
# SQLite version 3.42.0 2023-05-16 12:36:15
# Enter ".help" for usage hints.
#
#  create table emp_deatils
# (
#  e_id int,
#  e_fname varchar(20),
#  e_lname varchar(20),
#  email int,
#  phone_no int,
#  hier_date date,
#  job_id int,
#  salary int,
#  manager_id int,
#  department_id int
#  );
#
# sqlite> insert into emp_deatils
# values(1,'urvi','parmar','urvi07@gmail.com',9292929292,22-06-2023,011,25000,1001,1001);
#
# sqlite> insert into emp_deatils
# values(2,'vihan','parmar','vihu04@gmail.com',9275643293,20-06-2023,011,26000,1002,1002);
#
# sqlite> insert into emp_deatils
#  values(3,'siya','parmar','siya22@gmail.com',6739289273,17-06-2023,013,24000,1003,1003);
#
# sqlite> insert into emp_deatils
#  values(4,'ishita','parmar','ishu13@gmail.com',7345763212,18-06-2023,013,26000,1004,1004);
#
# sqlite> insert into emp_deatils
# ...
